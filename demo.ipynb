# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com' # set to hf-mirror if you cannot access huggingface.co
os.environ['HF_HOME'] = '/mnt/ssd1/zhanghanxiu/cache/huggingface'
os.environ['HF_HUB_OFFLINE'] = '1' # set to '1' to enable offline mode
os.environ["CUDA_VISIBLE_DEVICES"] = '3' # set to your GPU id
import warnings
warnings.filterwarnings("ignore")
import torch
torch.set_num_threads(4)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from utils import *

# %%
base_model_llama2 = "meta-llama/Llama-2-7b-hf"
base_model_qwen = "Qwen/Qwen2.5-7B"
finetune_model_list_qwen = ["Qwen/Qwen2.5-7B-Instruct", "Qwen/Qwen2.5-Math-7B","Qwen/Qwen2.5-Coder-7B","tablegpt/TableGPT2-7B","WangCa/Qwen2.5-7B-Medicine", "huihui-ai/Qwen2.5-7B-Instruct-abliterated-v2"]
finetune_model_list_llama2 = ["meta-llama/Llama-2-7b-chat-hf", "meta-llama/CodeLlama-7b-hf", "lmsys/vicuna-7b-v1.5", "WizardLMTeam/WizardMath-7B-V1.0", "EleutherAI/llemma_7b", "cxllin/Llama2-7b-Finance","LinkSoul/Chinese-Llama-2-7b"]
prune_model_list_llama2 = ["princeton-nlp/Sheared-LLaMA-2.7B", "nm-testing/SparseLlama-2-7b-pruned_50.2of4", "princeton-nlp/Sheared-LLaMA-1.3B-Pruned","princeton-nlp/Sheared-LLaMA-1.3B-ShareGPT","princeton-nlp/Sheared-LLaMA-2.7B-Pruned","princeton-nlp/Sheared-LLaMA-2.7B-ShareGPT","princeton-nlp/Sheared-LLaMA-1.3B","MBZUAI-LLM/GBLM-Pruner-LLaMA-2-7B",'/mnt/ssd1/zhanghanxiu/model/prune_wanda','/mnt/ssd1/zhanghanxiu/model/prune_sparsegpt']
unrelated_model_list_llama2 = ["mistralai/Mistral-7B-v0.3", "Qwen/Qwen1.5-7B", "baichuan-inc/Baichuan2-7B-Base", "internlm/internlm2_5-7b", "openai-community/gpt2-large","cerebras/Cerebras-GPT-1.3B","zai-org/chatglm2-6b", "facebook/opt-6.7b", "EleutherAI/pythia-6.9b", "mosaicml/mpt-7b"]
unrelated_model_list_qwen = ["mistralai/Mistral-7B-v0.3", "meta-llama/Llama-2-7b-hf", "baichuan-inc/Baichuan2-7B-Base", "internlm/internlm2_5-7b", "openai-community/gpt2-large","cerebras/Cerebras-GPT-1.3B","zai-org/chatglm2-6b", "facebook/opt-6.7b", "EleutherAI/pythia-6.9b", "mosaicml/mpt-7b"]

# %%
base_model_list_ds = ["Qwen/Qwen2.5-Math-1.5B","Qwen/Qwen2.5-Math-7B","meta-llama/Llama-3.1-8B"]
finetune_model_list_ds = ["deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B","deepseek-ai/DeepSeek-R1-Distill-Qwen-7B","deepseek-ai/DeepSeek-R1-Distill-Llama-8B"]

# %%
def print_distances(compare_func):

    print('--------------Qwen2.5-7B finetune--------------')
    for model_path in finetune_model_list_qwen:
        dist = compare_func(base_model_qwen, model_path)
        print(f"{model_path:60} {dist:>10.8f}")
    print('--------------Qwen2.5-7B unrelated--------------')
    for model_path in unrelated_model_list_qwen:
        dist = compare_func(base_model_qwen, model_path)
        print(f"{model_path:60} {dist:>10.8f}")
    print('--------------llama-2-7b unrelated--------------')
    for model_path in unrelated_model_list_llama2:
        dist = compare_func(base_model_llama2, model_path)
        print(f"{model_path:60} {dist:>10.8f}")
    print('--------------llama-2-7b finetune--------------')
    for model_path in finetune_model_list_llama2:
        dist = compare_func(base_model_llama2, model_path)
        print(f"{model_path:60} {dist:>10.8f}")
    print('-------------llama-2-7b pruned--------------')
    for model_path in prune_model_list_llama2:
        dist = compare_func(base_model_llama2, model_path)
        print(f"{model_path:60} {dist:>10.8f}")
    from itertools import combinations
    print('--------------pairwise distances for unrelated models--------------')
    for a, b in combinations(unrelated_model_list_llama2, 2):
        dist = compare_func(a, b)
        print(f"{a:40} <-> {b:40} {dist:>10.8f}")
    print('--------------deepseek models--------------')
    for i in range(3):
        dist = compare_func(base_model_list_ds[i], finetune_model_list_ds[i])
        print(f"{finetune_model_list_ds[i]:60} {dist:>10.8f}")

# %%
compare_func = lambda model_path_1, model_path_2: \
fp_dist_from_path(model_path_1=model_path_1, model_path_2=model_path_2, file_list=file_list, k=k, m=m)
print_distances(compare_func)
# Out:
# --------------Qwen2.5-7B finetune--------------
# Qwen/Qwen2.5-7B-Instruct                                     0.63304102
# Qwen/Qwen2.5-Math-7B                                         13.21428299
# Qwen/Qwen2.5-Coder-7B                                        20.97656250
# tablegpt/TableGPT2-7B                                        1.31297255
# WangCa/Qwen2.5-7B-Medicine                                   0.68328893
# huihui-ai/Qwen2.5-7B-Instruct-abliterated-v2                 0.63304102
# --------------Qwen2.5-7B unrelated--------------
# mistralai/Mistral-7B-v0.3                                    44.92657852
# meta-llama/Llama-2-7b-hf                                     57.42338943
# baichuan-inc/Baichuan2-7B-Base                               70.00093079
# internlm/internlm2_5-7b                                      55.70484924
# openai-community/gpt2-large                                  66.68096924
# cerebras/Cerebras-GPT-1.3B                                   88.02114105
# zai-org/chatglm2-6b                                          77.07314301
# facebook/opt-6.7b                                            118.02336884
# EleutherAI/pythia-6.9b                                       66.21716309
# mosaicml/mpt-7b                                              79.51844788
# --------------llama-2-7b unrelated--------------
# mistralai/Mistral-7B-v0.3                                    34.52864838
# Qwen/Qwen1.5-7B                                              44.37498856
# baichuan-inc/Baichuan2-7B-Base                               48.50079346
# internlm/internlm2_5-7b                                      65.03538513
# openai-community/gpt2-large                                  49.93957138
# cerebras/Cerebras-GPT-1.3B                                   67.37571716
# zai-org/chatglm2-6b                                          56.67109680
# facebook/opt-6.7b                                            108.38844299
# EleutherAI/pythia-6.9b                                       102.56100464
# mosaicml/mpt-7b                                              44.62456131
# --------------llama-2-7b finetune--------------
# meta-llama/Llama-2-7b-chat-hf                                0.82226062
# meta-llama/CodeLlama-7b-hf                                   12.66118622
# lmsys/vicuna-7b-v1.5                                         0.85975081
# WizardLMTeam/WizardMath-7B-V1.0                              0.45591342
# EleutherAI/llemma_7b                                         12.70500660
# cxllin/Llama2-7b-Finance                                     0.85040468
# LinkSoul/Chinese-Llama-2-7b                                  1.21470058
# -------------llama-2-7b pruned--------------
# princeton-nlp/Sheared-LLaMA-2.7B                             9.81222534
# nm-testing/SparseLlama-2-7b-pruned_50.2of4                   5.84381056
# princeton-nlp/Sheared-LLaMA-1.3B-Pruned                      23.25061035
# princeton-nlp/Sheared-LLaMA-1.3B-ShareGPT                    16.79705811
# princeton-nlp/Sheared-LLaMA-2.7B-Pruned                      11.04706383
# princeton-nlp/Sheared-LLaMA-2.7B-ShareGPT                    11.06105518
# princeton-nlp/Sheared-LLaMA-1.3B                             16.80613327
# MBZUAI-LLM/GBLM-Pruner-LLaMA-2-7B                            3.12292552
# /mnt/ssd1/zhanghanxiu/model/prune_wanda                      3.03259540
# /mnt/ssd1/zhanghanxiu/model/prune_sparsegpt                  2.75562382
# --------------pairwise distances for unrelated models--------------
# mistralai/Mistral-7B-v0.3                <-> Qwen/Qwen1.5-7B                          40.64183044
# mistralai/Mistral-7B-v0.3                <-> baichuan-inc/Baichuan2-7B-Base           50.72013855
# mistralai/Mistral-7B-v0.3                <-> internlm/internlm2_5-7b                  61.47255325
# mistralai/Mistral-7B-v0.3                <-> openai-community/gpt2-large              64.82286835
# mistralai/Mistral-7B-v0.3                <-> cerebras/Cerebras-GPT-1.3B               76.64265442
# mistralai/Mistral-7B-v0.3                <-> zai-org/chatglm2-6b                      47.92701721
# mistralai/Mistral-7B-v0.3                <-> facebook/opt-6.7b                        119.47317505
# mistralai/Mistral-7B-v0.3                <-> EleutherAI/pythia-6.9b                   101.01105499
# mistralai/Mistral-7B-v0.3                <-> mosaicml/mpt-7b                          62.95835114
# Qwen/Qwen1.5-7B                          <-> baichuan-inc/Baichuan2-7B-Base           48.94725800
# Qwen/Qwen1.5-7B                          <-> internlm/internlm2_5-7b                  53.57007599
# Qwen/Qwen1.5-7B                          <-> openai-community/gpt2-large              56.15595627
# Qwen/Qwen1.5-7B                          <-> cerebras/Cerebras-GPT-1.3B               75.60608673
# Qwen/Qwen1.5-7B                          <-> zai-org/chatglm2-6b                      66.08328247
# Qwen/Qwen1.5-7B                          <-> facebook/opt-6.7b                        112.94914246
# Qwen/Qwen1.5-7B                          <-> EleutherAI/pythia-6.9b                   84.25137329
# Qwen/Qwen1.5-7B                          <-> mosaicml/mpt-7b                          63.44178009
# baichuan-inc/Baichuan2-7B-Base           <-> internlm/internlm2_5-7b                  85.41940308
# baichuan-inc/Baichuan2-7B-Base           <-> openai-community/gpt2-large              53.68935013
# baichuan-inc/Baichuan2-7B-Base           <-> cerebras/Cerebras-GPT-1.3B               66.75563049
# baichuan-inc/Baichuan2-7B-Base           <-> zai-org/chatglm2-6b                      66.22547913
# baichuan-inc/Baichuan2-7B-Base           <-> facebook/opt-6.7b                        97.04144287
# baichuan-inc/Baichuan2-7B-Base           <-> EleutherAI/pythia-6.9b                   116.80850983
# baichuan-inc/Baichuan2-7B-Base           <-> mosaicml/mpt-7b                          52.94594574
# internlm/internlm2_5-7b                  <-> openai-community/gpt2-large              99.19822693
# internlm/internlm2_5-7b                  <-> cerebras/Cerebras-GPT-1.3B               119.83945465
# internlm/internlm2_5-7b                  <-> zai-org/chatglm2-6b                      94.60546112
# internlm/internlm2_5-7b                  <-> facebook/opt-6.7b                        158.56900024
# internlm/internlm2_5-7b                  <-> EleutherAI/pythia-6.9b                   46.96875000
# internlm/internlm2_5-7b                  <-> mosaicml/mpt-7b                          85.89456940
# openai-community/gpt2-large              <-> cerebras/Cerebras-GPT-1.3B               43.36963272
# openai-community/gpt2-large              <-> zai-org/chatglm2-6b                      72.79207611
# openai-community/gpt2-large              <-> facebook/opt-6.7b                        73.19906616
# openai-community/gpt2-large              <-> EleutherAI/pythia-6.9b                   118.07260132
# openai-community/gpt2-large              <-> mosaicml/mpt-7b                          52.00824356
# cerebras/Cerebras-GPT-1.3B               <-> zai-org/chatglm2-6b                      73.02028656
# cerebras/Cerebras-GPT-1.3B               <-> facebook/opt-6.7b                        60.10429382
# cerebras/Cerebras-GPT-1.3B               <-> EleutherAI/pythia-6.9b                   141.78802490
# cerebras/Cerebras-GPT-1.3B               <-> mosaicml/mpt-7b                          61.58200455
# zai-org/chatglm2-6b                      <-> facebook/opt-6.7b                        92.89074707
# zai-org/chatglm2-6b                      <-> EleutherAI/pythia-6.9b                   132.99240112
# zai-org/chatglm2-6b                      <-> mosaicml/mpt-7b                          69.60636902
# facebook/opt-6.7b                        <-> EleutherAI/pythia-6.9b                   167.15129089
# facebook/opt-6.7b                        <-> mosaicml/mpt-7b                          87.01797485
# EleutherAI/pythia-6.9b                   <-> mosaicml/mpt-7b                          122.96160889
# --------------deepseek models--------------
# deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B                    4.77572918
# deepseek-ai/DeepSeek-R1-Distill-Qwen-7B                      3.36502981
# deepseek-ai/DeepSeek-R1-Distill-Llama-8B                     4.78579807
